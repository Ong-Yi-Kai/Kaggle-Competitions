# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
import datatable as dt
import time
from flaml import AutoML

from numba import jit #to speed up loops

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
# Getting Data from folder
start = time.time()
train = dt.fread(r"C:\Users\Ong Yi Kai\Desktop\Data\Kaggle competitions\Tabular Data Oct 2021\train.csv").to_pandas()
test = dt.fread(r"C:\Users\Ong Yi Kai\Desktop\Data\Kaggle competitions\Tabular Data Oct 2021\test.csv").to_pandas()
end = time.time()
total_time = end-start
print("DONE LOADING! Time taken:{:.2f}".format(total_time))
# Out:
# DONE LOADING! Time taken:40.31

# %% [markdown]
# Reducing memeory usage (change data type)

# %%
# this function will help to reduce momory 
# data will be samller with the same value

@jit(forceobj=True)
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
        
            
    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
#reducing the memory of data types
train = reduce_mem_usage(train)
test = reduce_mem_usage(test)
# Out:
# Memory usage of dataframe is 1878.74 MB
# Memory usage after optimization is: 549.32 MB
# Decreased by 70.8%
# Memory usage of dataframe is 938.89 MB
# Memory usage after optimization is: 273.70 MB
# Decreased by 70.8%

# %% [markdown]
# splitting the data

# %%
# seperate data and target labels
X, y = train.iloc[:,1:-1], train.iloc[:,-1:]

# %%
# seperate test into ID and Data
ID_test = test.iloc[:,:1]
X_test = test.iloc[:,1:]

# %%
y = np.ravel(y)

# %% [markdown]
# AUTOML MODEL FIT

# %%
model = AutoML()

# %%
model.fit(X,y,metric='roc_auc', time_budget=5*3600,verbose=2)
# Out:
# [flaml.automl: 10-06 22:49:47] {1432} INFO - Evaluation method: holdout
# [flaml.automl: 10-06 22:49:53] {1478} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl: 10-06 22:49:53] {1515} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'catboost', 'xgboost', 'extra_tree', 'lrl1']
# [flaml.automl: 10-06 22:49:53] {1748} INFO - iteration 0, current learner lgbm
# [flaml.tune.tune: 10-06 22:49:54] {383} INFO - trial 1 config: {'n_estimators': 4, 'num_leaves': 4, 'min_child_samples': 20, 'learning_rate': 0.09999999999999995, 'log_max_bin': 8, 'colsample_bytree': 1.0, 'reg_alpha': 0.0009765625, 'reg_lambda': 1.0, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:49:54] {1865} INFO - Estimated sufficient time budget=906091s. Estimated necessary time budget=16446s.
# [flaml.automl: 10-06 22:49:54] {1938} INFO -  at 105.9s,	estimator lgbm's best error=0.2080,	best estimator lgbm's best error=0.2080
# [flaml.automl: 10-06 22:49:54] {1748} INFO - iteration 1, current learner lgbm
# [flaml.tune.tune: 10-06 22:49:54] {383} INFO - trial 1 config: {'n_estimators': 4, 'num_leaves': 4, 'min_child_samples': 33, 'learning_rate': 0.03735454900037746, 'log_max_bin': 9, 'colsample_bytree': 0.8085131463835397, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.692397057684401, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:49:55] {1938} INFO -  at 106.7s,	estimator lgbm's best error=0.1946,	best estimator lgbm's best error=0.1946
# [flaml.automl: 10-06 22:49:55] {1748} INFO - iteration 2, current learner lgbm
# [flaml.tune.tune: 10-06 22:49:55] {383} INFO - trial 1 config: {'n_estimators': 4, 'num_leaves': 4, 'min_child_samples': 20, 'learning_rate': 0.09999999999999995, 'log_max_bin': 8, 'colsample_bytree': 1.0, 'reg_alpha': 0.001348364934537134, 'reg_lambda': 1.0, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:49:56] {1938} INFO -  at 107.5s,	estimator lgbm's best error=0.1946,	best estimator lgbm's best error=0.1946
# [flaml.automl: 10-06 22:49:56] {1748} INFO - iteration 3, current learner lgbm
# [flaml.tune.tune: 10-06 22:49:56] {383} INFO - trial 1 config: {'n_estimators': 12, 'num_leaves': 4, 'min_child_samples': 25, 'learning_rate': 0.10131160192564638, 'log_max_bin': 10, 'colsample_bytree': 0.7370133750309855, 'reg_alpha': 0.002668211515123386, 'reg_lambda': 0.36111742401339153, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:49:57] {1938} INFO -  at 108.9s,	estimator lgbm's best error=0.1836,	best estimator lgbm's best error=0.1836
# [flaml.automl: 10-06 22:49:57] {1748} INFO - iteration 4, current learner xgboost
# [flaml.tune.tune: 10-06 22:49:57] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_leaves': 4, 'min_child_weight': 0.9999999999999993, 'learning_rate': 0.09999999999999995, 'subsample': 1.0, 'colsample_bylevel': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.0009765625, 'reg_lambda': 1.0, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:49:59] {1938} INFO -  at 110.2s,	estimator xgboost's best error=0.2081,	best estimator lgbm's best error=0.1836
# [flaml.automl: 10-06 22:49:59] {1748} INFO - iteration 5, current learner lgbm
# [flaml.tune.tune: 10-06 22:49:59] {383} INFO - trial 1 config: {'n_estimators': 4, 'num_leaves': 4, 'min_child_samples': 33, 'learning_rate': 0.03735454900037746, 'log_max_bin': 8, 'colsample_bytree': 0.8085131463835397, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.6923970576844015, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:00] {1938} INFO -  at 111.1s,	estimator lgbm's best error=0.1836,	best estimator lgbm's best error=0.1836
# [flaml.automl: 10-06 22:50:00] {1748} INFO - iteration 6, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:00] {383} INFO - trial 1 config: {'n_estimators': 14, 'num_leaves': 5, 'min_child_samples': 15, 'learning_rate': 0.10591441245329958, 'log_max_bin': 9, 'colsample_bytree': 0.6389203895134972, 'reg_alpha': 0.0014132988481787994, 'reg_lambda': 0.022976154325858374, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:01] {1938} INFO -  at 112.4s,	estimator lgbm's best error=0.1788,	best estimator lgbm's best error=0.1788
# [flaml.automl: 10-06 22:50:01] {1748} INFO - iteration 7, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:01] {383} INFO - trial 1 config: {'n_estimators': 12, 'num_leaves': 4, 'min_child_samples': 26, 'learning_rate': 0.10131160192564638, 'log_max_bin': 10, 'colsample_bytree': 0.7370133750309855, 'reg_alpha': 0.002668211515123386, 'reg_lambda': 0.36111742401339153, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:02] {1938} INFO -  at 113.7s,	estimator lgbm's best error=0.1788,	best estimator lgbm's best error=0.1788
# [flaml.automl: 10-06 22:50:02] {1748} INFO - iteration 8, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:02] {383} INFO - trial 1 config: {'n_estimators': 4, 'num_leaves': 6, 'min_child_samples': 20, 'learning_rate': 0.19173807345245308, 'log_max_bin': 9, 'colsample_bytree': 0.7082741990160921, 'reg_alpha': 0.012553125619676949, 'reg_lambda': 0.1186494209766889, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:03] {1938} INFO -  at 114.7s,	estimator lgbm's best error=0.1788,	best estimator lgbm's best error=0.1788
# [flaml.automl: 10-06 22:50:03] {1748} INFO - iteration 9, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:03] {383} INFO - trial 1 config: {'n_estimators': 53, 'num_leaves': 4, 'min_child_samples': 11, 'learning_rate': 0.05850618274888138, 'log_max_bin': 10, 'colsample_bytree': 0.5695665800109022, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.00444927302013027, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:05] {1938} INFO -  at 116.2s,	estimator lgbm's best error=0.1737,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:05] {1748} INFO - iteration 10, current learner xgboost
# [flaml.tune.tune: 10-06 22:50:05] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_leaves': 4, 'min_child_weight': 3.8156120279609143, 'learning_rate': 0.03859136192132082, 'subsample': 1.0, 'colsample_bylevel': 0.8148474110627004, 'colsample_bytree': 0.9777234800442423, 'reg_alpha': 0.0009765625, 'reg_lambda': 5.525802807180926, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:06] {1938} INFO -  at 117.4s,	estimator xgboost's best error=0.1945,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:06] {1748} INFO - iteration 11, current learner extra_tree
# [flaml.tune.tune: 10-06 22:50:06] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_features': 1.0, 'max_leaves': 4, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:06] {1938} INFO -  at 117.8s,	estimator extra_tree's best error=0.1993,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:06] {1748} INFO - iteration 12, current learner extra_tree
# [flaml.tune.tune: 10-06 22:50:06] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_features': 0.9692029582222275, 'max_leaves': 13, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:07] {1938} INFO -  at 118.3s,	estimator extra_tree's best error=0.1847,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:07] {1748} INFO - iteration 13, current learner extra_tree
# [flaml.tune.tune: 10-06 22:50:07] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_features': 0.9999999999999999, 'max_leaves': 4, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:07] {1938} INFO -  at 118.6s,	estimator extra_tree's best error=0.1847,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:07] {1748} INFO - iteration 14, current learner extra_tree
# [flaml.tune.tune: 10-06 22:50:07] {383} INFO - trial 1 config: {'n_estimators': 7, 'max_features': 0.639099828735494, 'max_leaves': 11, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:08] {1938} INFO -  at 119.1s,	estimator extra_tree's best error=0.1815,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:08] {1748} INFO - iteration 15, current learner rf
# [flaml.tune.tune: 10-06 22:50:08] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_features': 1.0, 'max_leaves': 4, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:09] {1938} INFO -  at 120.4s,	estimator rf's best error=0.2081,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:09] {1748} INFO - iteration 16, current learner rf
# [flaml.tune.tune: 10-06 22:50:09] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_features': 0.9692029582222275, 'max_leaves': 13, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:10] {1938} INFO -  at 121.9s,	estimator rf's best error=0.1868,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:10] {1748} INFO - iteration 17, current learner extra_tree
# [flaml.tune.tune: 10-06 22:50:10] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_features': 0.9692029582222269, 'max_leaves': 13, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:11] {1938} INFO -  at 122.5s,	estimator extra_tree's best error=0.1815,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:11] {1748} INFO - iteration 18, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:11] {383} INFO - trial 1 config: {'n_estimators': 15, 'num_leaves': 4, 'min_child_samples': 13, 'learning_rate': 0.1409664384951717, 'log_max_bin': 10, 'colsample_bytree': 0.6657052074144151, 'reg_alpha': 0.0013805492389047578, 'reg_lambda': 0.006107078007733911, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:13] {1938} INFO -  at 124.0s,	estimator lgbm's best error=0.1737,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:13] {1748} INFO - iteration 19, current learner xgboost
# [flaml.tune.tune: 10-06 22:50:13] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_leaves': 4, 'min_child_weight': 0.9999999999999981, 'learning_rate': 0.09999999999999995, 'subsample': 0.9266743941610592, 'colsample_bylevel': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.0013933617380144255, 'reg_lambda': 1.0, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:14] {1938} INFO -  at 125.4s,	estimator xgboost's best error=0.1945,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:14] {1748} INFO - iteration 20, current learner rf
# [flaml.tune.tune: 10-06 22:50:14] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_features': 0.9999999999999999, 'max_leaves': 4, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:15] {1938} INFO -  at 126.4s,	estimator rf's best error=0.1868,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:15] {1748} INFO - iteration 21, current learner rf
# [flaml.tune.tune: 10-06 22:50:15] {383} INFO - trial 1 config: {'n_estimators': 7, 'max_features': 0.639099828735494, 'max_leaves': 11, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:17] {1938} INFO -  at 128.8s,	estimator rf's best error=0.1814,	best estimator lgbm's best error=0.1737
# [flaml.automl: 10-06 22:50:17] {1748} INFO - iteration 22, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:17] {383} INFO - trial 1 config: {'n_estimators': 189, 'num_leaves': 20, 'min_child_samples': 9, 'learning_rate': 0.024282186997032957, 'log_max_bin': 10, 'colsample_bytree': 0.47342795260738935, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.003241489691566039, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:22] {1938} INFO -  at 133.3s,	estimator lgbm's best error=0.1649,	best estimator lgbm's best error=0.1649
# [flaml.automl: 10-06 22:50:22] {1748} INFO - iteration 23, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:22] {383} INFO - trial 1 config: {'n_estimators': 257, 'num_leaves': 25, 'min_child_samples': 7, 'learning_rate': 0.10577750092292157, 'log_max_bin': 10, 'colsample_bytree': 0.40989107964524396, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.0009765625, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:28] {1938} INFO -  at 139.4s,	estimator lgbm's best error=0.1649,	best estimator lgbm's best error=0.1649
# [flaml.automl: 10-06 22:50:28] {1748} INFO - iteration 24, current learner xgboost
# [flaml.tune.tune: 10-06 22:50:28] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_leaves': 4, 'min_child_weight': 27.123547475701166, 'learning_rate': 0.14971979531690335, 'subsample': 0.9246883402776727, 'colsample_bylevel': 0.898014219139486, 'colsample_bytree': 0.9238615531554782, 'reg_alpha': 0.0012834136471904583, 'reg_lambda': 8.519631194693345, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:29] {1938} INFO -  at 140.7s,	estimator xgboost's best error=0.1896,	best estimator lgbm's best error=0.1649
# [flaml.automl: 10-06 22:50:29] {1748} INFO - iteration 25, current learner extra_tree
# [flaml.tune.tune: 10-06 22:50:29] {383} INFO - trial 1 config: {'n_estimators': 15, 'max_features': 0.6371266925881748, 'max_leaves': 6, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:30] {1938} INFO -  at 141.2s,	estimator extra_tree's best error=0.1815,	best estimator lgbm's best error=0.1649
# [flaml.automl: 10-06 22:50:30] {1748} INFO - iteration 26, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:30] {383} INFO - trial 1 config: {'n_estimators': 139, 'num_leaves': 16, 'min_child_samples': 11, 'learning_rate': 0.005574196783005176, 'log_max_bin': 9, 'colsample_bytree': 0.5369648255695347, 'reg_alpha': 0.001538995396757784, 'reg_lambda': 0.01705653951856333, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:33] {1938} INFO -  at 144.1s,	estimator lgbm's best error=0.1649,	best estimator lgbm's best error=0.1649
# [flaml.automl: 10-06 22:50:33] {1748} INFO - iteration 27, current learner xgboost
# [flaml.tune.tune: 10-06 22:50:33] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_leaves': 8, 'min_child_weight': 3.815612027960904, 'learning_rate': 0.03859136192132082, 'subsample': 1.0, 'colsample_bylevel': 0.8148474110627004, 'colsample_bytree': 0.9777234800442423, 'reg_alpha': 0.0009765625, 'reg_lambda': 5.525802807180926, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:34] {1938} INFO -  at 145.4s,	estimator xgboost's best error=0.1896,	best estimator lgbm's best error=0.1649
# [flaml.automl: 10-06 22:50:34] {1748} INFO - iteration 28, current learner extra_tree
# [flaml.tune.tune: 10-06 22:50:34] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_features': 0.6410790755454192, 'max_leaves': 20, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:34] {1938} INFO -  at 145.8s,	estimator extra_tree's best error=0.1815,	best estimator lgbm's best error=0.1649
# [flaml.automl: 10-06 22:50:34] {1748} INFO - iteration 29, current learner extra_tree
# [flaml.tune.tune: 10-06 22:50:34] {383} INFO - trial 1 config: {'n_estimators': 20, 'max_features': 0.5424809996248551, 'max_leaves': 21, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:35] {1938} INFO -  at 146.6s,	estimator extra_tree's best error=0.1809,	best estimator lgbm's best error=0.1649
# [flaml.automl: 10-06 22:50:35] {1748} INFO - iteration 30, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:35] {383} INFO - trial 1 config: {'n_estimators': 318, 'num_leaves': 4, 'min_child_samples': 8, 'learning_rate': 0.04519994067959539, 'log_max_bin': 10, 'colsample_bytree': 0.541558149982507, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.011560290084572896, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:38] {1938} INFO -  at 149.3s,	estimator lgbm's best error=0.1608,	best estimator lgbm's best error=0.1608
# [flaml.automl: 10-06 22:50:38] {1748} INFO - iteration 31, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:38] {383} INFO - trial 1 config: {'n_estimators': 189, 'num_leaves': 19, 'min_child_samples': 9, 'learning_rate': 0.024282186997032957, 'log_max_bin': 9, 'colsample_bytree': 0.4734279526073894, 'reg_alpha': 0.006958608037974516, 'reg_lambda': 0.0032414896915660394, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:41] {1938} INFO -  at 152.8s,	estimator lgbm's best error=0.1608,	best estimator lgbm's best error=0.1608
# [flaml.automl: 10-06 22:50:41] {1748} INFO - iteration 32, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:41] {383} INFO - trial 1 config: {'n_estimators': 276, 'num_leaves': 16, 'min_child_samples': 7, 'learning_rate': 0.17907552667096496, 'log_max_bin': 10, 'colsample_bytree': 0.6290920542071692, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.00593849681857357, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:47] {1938} INFO -  at 158.7s,	estimator lgbm's best error=0.1608,	best estimator lgbm's best error=0.1608
# [flaml.automl: 10-06 22:50:47] {1748} INFO - iteration 33, current learner xgboost
# [flaml.tune.tune: 10-06 22:50:47] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_leaves': 4, 'min_child_weight': 8.551327855112987, 'learning_rate': 0.0794265994730958, 'subsample': 0.8866076531034812, 'colsample_bylevel': 0.7164309072871456, 'colsample_bytree': 0.788744259288662, 'reg_alpha': 0.0017273290408679647, 'reg_lambda': 19.450171169544824, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:49] {1938} INFO -  at 159.9s,	estimator xgboost's best error=0.1896,	best estimator lgbm's best error=0.1608
# [flaml.automl: 10-06 22:50:49] {1748} INFO - iteration 34, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:49] {383} INFO - trial 1 config: {'n_estimators': 367, 'num_leaves': 4, 'min_child_samples': 9, 'learning_rate': 0.011408787540202704, 'log_max_bin': 9, 'colsample_bytree': 0.4540242457578447, 'reg_alpha': 0.001858538296879656, 'reg_lambda': 0.022504063052032567, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:50:51] {1938} INFO -  at 162.4s,	estimator lgbm's best error=0.1608,	best estimator lgbm's best error=0.1608
# [flaml.automl: 10-06 22:50:51] {1748} INFO - iteration 35, current learner lgbm
# [flaml.tune.tune: 10-06 22:50:51] {383} INFO - trial 1 config: {'n_estimators': 318, 'num_leaves': 4, 'min_child_samples': 8, 'learning_rate': 0.04519994067959539, 'log_max_bin': 10, 'colsample_bytree': 0.541558149982507, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.011560290084572896, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:50:57] {1938} INFO -  at 168.8s,	estimator lgbm's best error=0.1577,	best estimator lgbm's best error=0.1577
# [flaml.automl: 10-06 22:50:57] {1748} INFO - iteration 36, current learner catboost
# [flaml.tune.tune: 10-06 22:50:57] {383} INFO - trial 1 config: {'early_stopping_rounds': 10, 'learning_rate': 0.09999999999999996, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:51:11] {1938} INFO -  at 182.4s,	estimator catboost's best error=0.1656,	best estimator lgbm's best error=0.1577
# [flaml.automl: 10-06 22:51:11] {1748} INFO - iteration 37, current learner xgboost
# [flaml.tune.tune: 10-06 22:51:11] {383} INFO - trial 1 config: {'n_estimators': 12, 'max_leaves': 4, 'min_child_weight': 86.03188184706697, 'learning_rate': 0.28222304943734144, 'subsample': 0.9627690274518641, 'colsample_bylevel': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.0009765625, 'reg_lambda': 3.731798299402348, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:51:13] {1938} INFO -  at 184.0s,	estimator xgboost's best error=0.1752,	best estimator lgbm's best error=0.1577
# [flaml.automl: 10-06 22:51:13] {1748} INFO - iteration 38, current learner catboost
# [flaml.tune.tune: 10-06 22:51:13] {383} INFO - trial 1 config: {'early_stopping_rounds': 10, 'learning_rate': 0.005, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:51:32] {1938} INFO -  at 202.9s,	estimator catboost's best error=0.1656,	best estimator lgbm's best error=0.1577
# [flaml.automl: 10-06 22:51:32] {1748} INFO - iteration 39, current learner xgboost
# [flaml.tune.tune: 10-06 22:51:32] {383} INFO - trial 1 config: {'n_estimators': 23, 'max_leaves': 4, 'min_child_weight': 128.0, 'learning_rate': 0.7246388364154469, 'subsample': 1.0, 'colsample_bylevel': 0.8811171114303163, 'colsample_bytree': 0.8499027725496043, 'reg_alpha': 0.0015851927568202393, 'reg_lambda': 16.6737497669411, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:51:33] {1938} INFO -  at 204.6s,	estimator xgboost's best error=0.1642,	best estimator lgbm's best error=0.1577
# [flaml.automl: 10-06 22:51:33] {1748} INFO - iteration 40, current learner xgboost
# [flaml.tune.tune: 10-06 22:51:33] {383} INFO - trial 1 config: {'n_estimators': 12, 'max_leaves': 6, 'min_child_weight': 62.843451815188914, 'learning_rate': 0.28222304943734167, 'subsample': 0.9079647052885418, 'colsample_bylevel': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.0009765625, 'reg_lambda': 3.731798299402348, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:51:35] {1938} INFO -  at 206.4s,	estimator xgboost's best error=0.1642,	best estimator lgbm's best error=0.1577
# [flaml.automl: 10-06 22:51:35] {1748} INFO - iteration 41, current learner xgboost
# [flaml.tune.tune: 10-06 22:51:35] {383} INFO - trial 1 config: {'n_estimators': 22, 'max_leaves': 12, 'min_child_weight': 128.0, 'learning_rate': 0.8825554243623319, 'subsample': 1.0, 'colsample_bylevel': 0.9088550158793876, 'colsample_bytree': 0.7967145599266738, 'reg_alpha': 0.040774029561503077, 'reg_lambda': 84.16397655137418, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:51:37] {1938} INFO -  at 208.5s,	estimator xgboost's best error=0.1642,	best estimator lgbm's best error=0.1577
# [flaml.automl: 10-06 22:51:37] {1748} INFO - iteration 42, current learner xgboost
# [flaml.tune.tune: 10-06 22:51:37] {383} INFO - trial 1 config: {'n_estimators': 24, 'max_leaves': 4, 'min_child_weight': 88.80189521607865, 'learning_rate': 0.5949784327946674, 'subsample': 0.9661106209889765, 'colsample_bylevel': 0.853379206981245, 'colsample_bytree': 0.9030909851725347, 'reg_alpha': 0.0009765625, 'reg_lambda': 3.303241394741693, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:51:39] {1938} INFO -  at 210.4s,	estimator xgboost's best error=0.1642,	best estimator lgbm's best error=0.1577
# [flaml.automl: 10-06 22:51:39] {1748} INFO - iteration 43, current learner lgbm
# [flaml.tune.tune: 10-06 22:51:39] {383} INFO - trial 1 config: {'n_estimators': 183, 'num_leaves': 17, 'min_child_samples': 6, 'learning_rate': 0.03975596653027463, 'log_max_bin': 10, 'colsample_bytree': 0.6229741816501054, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.021711381455942185, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:51:48] {1938} INFO -  at 219.2s,	estimator lgbm's best error=0.1570,	best estimator lgbm's best error=0.1570
# [flaml.automl: 10-06 22:51:48] {1748} INFO - iteration 44, current learner xgboost
# [flaml.tune.tune: 10-06 22:51:48] {383} INFO - trial 1 config: {'n_estimators': 12, 'max_leaves': 4, 'min_child_weight': 24.99201451811334, 'learning_rate': 1.0, 'subsample': 0.8286310106576346, 'colsample_bylevel': 0.83710445344523, 'colsample_bytree': 0.9485956837704628, 'reg_alpha': 0.004467085234725363, 'reg_lambda': 48.172722889266595, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:51:50] {1938} INFO -  at 220.9s,	estimator xgboost's best error=0.1642,	best estimator lgbm's best error=0.1570
# [flaml.automl: 10-06 22:51:50] {1748} INFO - iteration 45, current learner extra_tree
# [flaml.tune.tune: 10-06 22:51:50] {383} INFO - trial 1 config: {'n_estimators': 7, 'max_features': 0.6390998287354936, 'max_leaves': 11, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:51:50] {1938} INFO -  at 221.4s,	estimator extra_tree's best error=0.1809,	best estimator lgbm's best error=0.1570
# [flaml.automl: 10-06 22:51:50] {1748} INFO - iteration 46, current learner xgboost
# [flaml.tune.tune: 10-06 22:51:50] {383} INFO - trial 1 config: {'n_estimators': 23, 'max_leaves': 4, 'min_child_weight': 128.0, 'learning_rate': 0.7246388364154469, 'subsample': 1.0, 'colsample_bylevel': 0.8811171114303163, 'colsample_bytree': 0.8499027725496043, 'reg_alpha': 0.0015851927568202393, 'reg_lambda': 16.6737497669411, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:51:54] {1938} INFO -  at 225.1s,	estimator xgboost's best error=0.1592,	best estimator lgbm's best error=0.1570
# [flaml.automl: 10-06 22:51:54] {1748} INFO - iteration 47, current learner lgbm
# [flaml.tune.tune: 10-06 22:51:54] {383} INFO - trial 1 config: {'n_estimators': 319, 'num_leaves': 4, 'min_child_samples': 8, 'learning_rate': 0.04519994067959539, 'log_max_bin': 8, 'colsample_bytree': 0.541558149982507, 'reg_alpha': 0.0017271108100233477, 'reg_lambda': 0.011560290084572896, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:51:59] {1938} INFO -  at 230.2s,	estimator lgbm's best error=0.1570,	best estimator lgbm's best error=0.1570
# [flaml.automl: 10-06 22:51:59] {1748} INFO - iteration 48, current learner xgboost
# [flaml.tune.tune: 10-06 22:51:59] {383} INFO - trial 1 config: {'n_estimators': 7, 'max_leaves': 8, 'min_child_weight': 107.69590113017051, 'learning_rate': 1.0, 'subsample': 0.9728097438800569, 'colsample_bylevel': 1.0, 'colsample_bytree': 0.8948230026622657, 'reg_alpha': 0.004921077295821346, 'reg_lambda': 9.19912194611776, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:52:02] {1938} INFO -  at 233.8s,	estimator xgboost's best error=0.1592,	best estimator lgbm's best error=0.1570
# [flaml.automl: 10-06 22:52:02] {1748} INFO - iteration 49, current learner lgbm
# [flaml.tune.tune: 10-06 22:52:02] {383} INFO - trial 1 config: {'n_estimators': 87, 'num_leaves': 8, 'min_child_samples': 7, 'learning_rate': 0.12253425750631962, 'log_max_bin': 10, 'colsample_bytree': 0.7700247033676194, 'reg_alpha': 0.0015564673105246886, 'reg_lambda': 0.014120003302197788, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:52:07] {1938} INFO -  at 238.7s,	estimator lgbm's best error=0.1565,	best estimator lgbm's best error=0.1565
# [flaml.automl: 10-06 22:52:07] {1748} INFO - iteration 50, current learner rf
# [flaml.tune.tune: 10-06 22:52:07] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_features': 0.9692029582222269, 'max_leaves': 13, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:52:09] {1938} INFO -  at 240.5s,	estimator rf's best error=0.1814,	best estimator lgbm's best error=0.1565
# [flaml.automl: 10-06 22:52:09] {1748} INFO - iteration 51, current learner xgboost
# [flaml.tune.tune: 10-06 22:52:09] {383} INFO - trial 1 config: {'n_estimators': 74, 'max_leaves': 4, 'min_child_weight': 128.0, 'learning_rate': 0.26565170711469355, 'subsample': 1.0, 'colsample_bylevel': 0.6993908476086765, 'colsample_bytree': 0.804982542436943, 'reg_alpha': 0.0009765625, 'reg_lambda': 30.22178996201878, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:52:14] {1938} INFO -  at 245.4s,	estimator xgboost's best error=0.1557,	best estimator xgboost's best error=0.1557
# [flaml.automl: 10-06 22:52:14] {1748} INFO - iteration 52, current learner catboost
# [flaml.tune.tune: 10-06 22:52:14] {383} INFO - trial 1 config: {'early_stopping_rounds': 11, 'learning_rate': 0.2, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:52:24] {1938} INFO -  at 255.9s,	estimator catboost's best error=0.1656,	best estimator xgboost's best error=0.1557
# [flaml.automl: 10-06 22:52:24] {1748} INFO - iteration 53, current learner catboost
# [flaml.tune.tune: 10-06 22:52:24] {383} INFO - trial 1 config: {'early_stopping_rounds': 11, 'learning_rate': 0.005, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:52:43] {1938} INFO -  at 274.2s,	estimator catboost's best error=0.1656,	best estimator xgboost's best error=0.1557
# [flaml.automl: 10-06 22:52:43] {1748} INFO - iteration 54, current learner lgbm
# [flaml.tune.tune: 10-06 22:52:43] {383} INFO - trial 1 config: {'n_estimators': 183, 'num_leaves': 18, 'min_child_samples': 6, 'learning_rate': 0.03975596653027463, 'log_max_bin': 9, 'colsample_bytree': 0.6229741816501054, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.021711381455942185, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:52:50] {1938} INFO -  at 281.3s,	estimator lgbm's best error=0.1565,	best estimator xgboost's best error=0.1557
# [flaml.automl: 10-06 22:52:50] {1748} INFO - iteration 55, current learner lgbm
# [flaml.tune.tune: 10-06 22:52:50] {383} INFO - trial 1 config: {'n_estimators': 174, 'num_leaves': 4, 'min_child_samples': 3, 'learning_rate': 0.15137582328109456, 'log_max_bin': 10, 'colsample_bytree': 0.8202127157966069, 'reg_alpha': 0.007296238964396976, 'reg_lambda': 0.030276835365454145, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:52:55] {1938} INFO -  at 286.3s,	estimator lgbm's best error=0.1532,	best estimator lgbm's best error=0.1532
# [flaml.automl: 10-06 22:52:55] {1748} INFO - iteration 56, current learner xgboost
# [flaml.tune.tune: 10-06 22:52:55] {383} INFO - trial 1 config: {'n_estimators': 40, 'max_leaves': 4, 'min_child_weight': 128.0, 'learning_rate': 0.1592525655531112, 'subsample': 0.9827721799620315, 'colsample_bylevel': 0.8902313359373609, 'colsample_bytree': 0.8891560141847119, 'reg_alpha': 0.0009765625, 'reg_lambda': 57.98415803668586, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:53:00] {1938} INFO -  at 291.1s,	estimator xgboost's best error=0.1557,	best estimator lgbm's best error=0.1532
# [flaml.automl: 10-06 22:53:00] {1748} INFO - iteration 57, current learner lgbm
# [flaml.tune.tune: 10-06 22:53:00] {383} INFO - trial 1 config: {'n_estimators': 87, 'num_leaves': 9, 'min_child_samples': 7, 'learning_rate': 0.12253425750631962, 'log_max_bin': 9, 'colsample_bytree': 0.7700247033676194, 'reg_alpha': 0.0015564673105246888, 'reg_lambda': 0.014120003302197788, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:53:04] {1938} INFO -  at 295.4s,	estimator lgbm's best error=0.1532,	best estimator lgbm's best error=0.1532
# [flaml.automl: 10-06 22:53:04] {1748} INFO - iteration 58, current learner lgbm
# [flaml.tune.tune: 10-06 22:53:04] {383} INFO - trial 1 config: {'n_estimators': 245, 'num_leaves': 4, 'min_child_samples': 3, 'learning_rate': 0.06138649796726537, 'log_max_bin': 10, 'colsample_bytree': 1.0, 'reg_alpha': 0.010059740218605017, 'reg_lambda': 0.05383690362772219, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:53:10] {1938} INFO -  at 301.8s,	estimator lgbm's best error=0.1532,	best estimator lgbm's best error=0.1532
# [flaml.automl: 10-06 22:53:10] {1748} INFO - iteration 59, current learner rf
# [flaml.tune.tune: 10-06 22:53:10] {383} INFO - trial 1 config: {'n_estimators': 15, 'max_features': 0.6371266925881748, 'max_leaves': 6, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:53:13] {1938} INFO -  at 304.2s,	estimator rf's best error=0.1814,	best estimator lgbm's best error=0.1532
# [flaml.automl: 10-06 22:53:13] {1748} INFO - iteration 60, current learner lgbm
# [flaml.tune.tune: 10-06 22:53:13] {383} INFO - trial 1 config: {'n_estimators': 123, 'num_leaves': 11, 'min_child_samples': 3, 'learning_rate': 0.37328469016506705, 'log_max_bin': 10, 'colsample_bytree': 0.6125955852734093, 'reg_alpha': 0.005291896397794531, 'reg_lambda': 0.017027107763953678, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:53:18] {1938} INFO -  at 309.5s,	estimator lgbm's best error=0.1532,	best estimator lgbm's best error=0.1532
# [flaml.automl: 10-06 22:53:18] {1748} INFO - iteration 61, current learner catboost
# [flaml.tune.tune: 10-06 22:53:18] {383} INFO - trial 1 config: {'early_stopping_rounds': 10, 'learning_rate': 0.2, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:53:28] {1938} INFO -  at 319.8s,	estimator catboost's best error=0.1656,	best estimator lgbm's best error=0.1532
# [flaml.automl: 10-06 22:53:28] {1748} INFO - iteration 62, current learner lgbm
# [flaml.tune.tune: 10-06 22:53:28] {383} INFO - trial 1 config: {'n_estimators': 109, 'num_leaves': 23, 'min_child_samples': 2, 'learning_rate': 0.0937699137191005, 'log_max_bin': 10, 'colsample_bytree': 0.7648193592201722, 'reg_alpha': 0.003210901040683456, 'reg_lambda': 0.05120176240337406, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:53:36] {1938} INFO -  at 327.5s,	estimator lgbm's best error=0.1532,	best estimator lgbm's best error=0.1532
# [flaml.automl: 10-06 22:53:36] {1748} INFO - iteration 63, current learner xgboost
# [flaml.tune.tune: 10-06 22:53:36] {383} INFO - trial 1 config: {'n_estimators': 135, 'max_leaves': 7, 'min_child_weight': 18.377290619905157, 'learning_rate': 0.4431377871235321, 'subsample': 1.0, 'colsample_bylevel': 0.508550359279992, 'colsample_bytree': 0.7208090706891741, 'reg_alpha': 0.0017607866203119683, 'reg_lambda': 15.7518298003139, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:53:43] {1938} INFO -  at 334.7s,	estimator xgboost's best error=0.1557,	best estimator lgbm's best error=0.1532
# [flaml.automl: 10-06 22:53:43] {1748} INFO - iteration 64, current learner xgboost
# [flaml.tune.tune: 10-06 22:53:43] {383} INFO - trial 1 config: {'n_estimators': 34, 'max_leaves': 4, 'min_child_weight': 128.0, 'learning_rate': 0.8519848967173336, 'subsample': 1.0, 'colsample_bylevel': 0.8516345054470446, 'colsample_bytree': 0.8394464336520354, 'reg_alpha': 0.0009765625, 'reg_lambda': 74.61134960675294, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:53:47] {1938} INFO -  at 338.6s,	estimator xgboost's best error=0.1557,	best estimator lgbm's best error=0.1532
# [flaml.automl: 10-06 22:53:47] {1748} INFO - iteration 65, current learner lgbm
# [flaml.tune.tune: 10-06 22:53:47] {383} INFO - trial 1 config: {'n_estimators': 174, 'num_leaves': 4, 'min_child_samples': 3, 'learning_rate': 0.15137582328109456, 'log_max_bin': 10, 'colsample_bytree': 0.8202127157966069, 'reg_alpha': 0.007296238964396976, 'reg_lambda': 0.030276835365454145, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-06 22:54:04] {1938} INFO -  at 355.5s,	estimator lgbm's best error=0.1522,	best estimator lgbm's best error=0.1522
# [flaml.automl: 10-06 22:54:04] {1748} INFO - iteration 66, current learner rf
# [flaml.tune.tune: 10-06 22:54:04] {383} INFO - trial 1 config: {'n_estimators': 4, 'max_features': 0.6410790755454192, 'max_leaves': 20, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:54:05] {1938} INFO -  at 356.6s,	estimator rf's best error=0.1814,	best estimator lgbm's best error=0.1522
# [flaml.automl: 10-06 22:54:05] {1748} INFO - iteration 67, current learner xgboost
# [flaml.tune.tune: 10-06 22:54:05] {383} INFO - trial 1 config: {'n_estimators': 160, 'max_leaves': 9, 'min_child_weight': 93.72300482528745, 'learning_rate': 0.08283108041569484, 'subsample': 0.8895588746662894, 'colsample_bylevel': 0.5471471897703085, 'colsample_bytree': 0.7705186512218506, 'reg_alpha': 0.0015245843735931768, 'reg_lambda': 12.241523485667024, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:54:17] {1938} INFO -  at 368.3s,	estimator xgboost's best error=0.1541,	best estimator lgbm's best error=0.1522
# [flaml.automl: 10-06 22:54:17] {1748} INFO - iteration 68, current learner rf
# [flaml.tune.tune: 10-06 22:54:17] {383} INFO - trial 1 config: {'n_estimators': 20, 'max_features': 0.5424809996248551, 'max_leaves': 21, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:54:20] {1938} INFO -  at 371.3s,	estimator rf's best error=0.1789,	best estimator lgbm's best error=0.1522
# [flaml.automl: 10-06 22:54:20] {1748} INFO - iteration 69, current learner lgbm
# [flaml.tune.tune: 10-06 22:54:20] {383} INFO - trial 1 config: {'n_estimators': 386, 'num_leaves': 8, 'min_child_samples': 2, 'learning_rate': 0.28049353064472504, 'log_max_bin': 8, 'colsample_bytree': 0.7129103012368956, 'reg_alpha': 0.0014261178916043912, 'reg_lambda': 0.051780834846482625, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-06 22:54:42] {1938} INFO -  at 393.0s,	estimator lgbm's best error=0.1512,	best estimator lgbm's best error=0.1512
# [flaml.automl: 10-06 22:54:42] {1748} INFO - iteration 70, current learner lgbm
# [flaml.tune.tune: 10-06 22:54:42] {383} INFO - trial 1 config: {'n_estimators': 174, 'num_leaves': 4, 'min_child_samples': 3, 'learning_rate': 0.15137582328109456, 'log_max_bin': 10, 'colsample_bytree': 0.8202127157966069, 'reg_alpha': 0.007296238964396976, 'reg_lambda': 0.030276835365454134, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-06 22:54:59] {1938} INFO -  at 410.2s,	estimator lgbm's best error=0.1512,	best estimator lgbm's best error=0.1512
# [flaml.automl: 10-06 22:54:59] {1748} INFO - iteration 71, current learner catboost
# [flaml.tune.tune: 10-06 22:54:59] {383} INFO - trial 1 config: {'early_stopping_rounds': 10, 'learning_rate': 0.09999999999999996, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:55:25] {1938} INFO -  at 436.6s,	estimator catboost's best error=0.1537,	best estimator lgbm's best error=0.1512
# [flaml.automl: 10-06 22:55:25] {1748} INFO - iteration 72, current learner lgbm
# [flaml.tune.tune: 10-06 22:55:25] {383} INFO - trial 1 config: {'n_estimators': 243, 'num_leaves': 4, 'min_child_samples': 2, 'learning_rate': 0.09973479897578325, 'log_max_bin': 7, 'colsample_bytree': 0.6679019480960846, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.006780113285509661, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-06 22:55:41] {1938} INFO -  at 452.5s,	estimator lgbm's best error=0.1512,	best estimator lgbm's best error=0.1512
# [flaml.automl: 10-06 22:55:41] {1748} INFO - iteration 73, current learner extra_tree
# [flaml.tune.tune: 10-06 22:55:41] {383} INFO - trial 1 config: {'n_estimators': 23, 'max_features': 0.5937078944174348, 'max_leaves': 4, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:55:42] {1938} INFO -  at 453.0s,	estimator extra_tree's best error=0.1809,	best estimator lgbm's best error=0.1512
# [flaml.automl: 10-06 22:55:42] {1748} INFO - iteration 74, current learner rf
# [flaml.tune.tune: 10-06 22:55:42] {383} INFO - trial 1 config: {'n_estimators': 7, 'max_features': 0.6390998287354936, 'max_leaves': 11, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:55:43] {1938} INFO -  at 454.5s,	estimator rf's best error=0.1789,	best estimator lgbm's best error=0.1512
# [flaml.automl: 10-06 22:55:43] {1748} INFO - iteration 75, current learner xgboost
# [flaml.tune.tune: 10-06 22:55:43] {383} INFO - trial 1 config: {'n_estimators': 71, 'max_leaves': 4, 'min_child_weight': 128.0, 'learning_rate': 0.14280879288372614, 'subsample': 0.937812919568431, 'colsample_bylevel': 0.663832947587693, 'colsample_bytree': 0.828130444585856, 'reg_alpha': 0.00219619032371591, 'reg_lambda': 4.031473327833151, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:55:49] {1938} INFO -  at 460.4s,	estimator xgboost's best error=0.1541,	best estimator lgbm's best error=0.1512
# [flaml.automl: 10-06 22:55:49] {1748} INFO - iteration 76, current learner lgbm
# [flaml.tune.tune: 10-06 22:55:49] {383} INFO - trial 1 config: {'n_estimators': 613, 'num_leaves': 28, 'min_child_samples': 2, 'learning_rate': 0.7888582675405692, 'log_max_bin': 9, 'colsample_bytree': 0.7579186543777067, 'reg_alpha': 0.004492803488093183, 'reg_lambda': 0.3954587105688986, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-06 22:56:31] {1938} INFO -  at 502.4s,	estimator lgbm's best error=0.1512,	best estimator lgbm's best error=0.1512
# [flaml.automl: 10-06 22:56:31] {1748} INFO - iteration 77, current learner lgbm
# [flaml.tune.tune: 10-06 22:56:31] {383} INFO - trial 1 config: {'n_estimators': 151, 'num_leaves': 18, 'min_child_samples': 2, 'learning_rate': 0.3333134055055376, 'log_max_bin': 7, 'colsample_bytree': 0.6543558782349936, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.04998042591995087, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-06 22:56:48] {1938} INFO -  at 519.0s,	estimator lgbm's best error=0.1512,	best estimator lgbm's best error=0.1512
# [flaml.automl: 10-06 22:56:48] {1748} INFO - iteration 78, current learner xgboost
# [flaml.tune.tune: 10-06 22:56:48] {383} INFO - trial 1 config: {'n_estimators': 363, 'max_leaves': 64, 'min_child_weight': 64.14004485500153, 'learning_rate': 0.0480431753835877, 'subsample': 0.8413048297641477, 'colsample_bylevel': 0.430461431952924, 'colsample_bytree': 0.712906857857845, 'reg_alpha': 0.001058358871316641, 'reg_lambda': 37.17124858932945, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:57:35] {1938} INFO -  at 566.0s,	estimator xgboost's best error=0.1526,	best estimator lgbm's best error=0.1512
# [flaml.automl: 10-06 22:57:35] {1748} INFO - iteration 79, current learner catboost
# [flaml.tune.tune: 10-06 22:57:35] {383} INFO - trial 1 config: {'early_stopping_rounds': 11, 'learning_rate': 0.005, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 22:58:02] {1938} INFO -  at 593.8s,	estimator catboost's best error=0.1537,	best estimator lgbm's best error=0.1512
# [flaml.automl: 10-06 22:58:02] {1748} INFO - iteration 80, current learner lgbm
# [flaml.tune.tune: 10-06 22:58:02] {383} INFO - trial 1 config: {'n_estimators': 386, 'num_leaves': 8, 'min_child_samples': 2, 'learning_rate': 0.28049353064472504, 'log_max_bin': 8, 'colsample_bytree': 0.7129103012368956, 'reg_alpha': 0.0014261178916043912, 'reg_lambda': 0.051780834846482625, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-06 22:59:42] {1938} INFO -  at 693.8s,	estimator lgbm's best error=0.1455,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 22:59:42] {1748} INFO - iteration 81, current learner extra_tree
# [flaml.tune.tune: 10-06 22:59:42] {383} INFO - trial 1 config: {'n_estimators': 17, 'max_features': 0.495674114697, 'max_leaves': 121, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:59:43] {1938} INFO -  at 694.8s,	estimator extra_tree's best error=0.1809,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 22:59:43] {1748} INFO - iteration 82, current learner rf
# [flaml.tune.tune: 10-06 22:59:43] {383} INFO - trial 1 config: {'n_estimators': 23, 'max_features': 0.5937078944174348, 'max_leaves': 4, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 22:59:45] {1938} INFO -  at 696.7s,	estimator rf's best error=0.1789,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 22:59:45] {1748} INFO - iteration 83, current learner catboost
# [flaml.tune.tune: 10-06 22:59:45] {383} INFO - trial 1 config: {'early_stopping_rounds': 10, 'learning_rate': 0.2, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 23:00:01] {1938} INFO -  at 712.6s,	estimator catboost's best error=0.1537,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:00:01] {1748} INFO - iteration 84, current learner lrl1
# No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'.
# [flaml.tune.tune: 10-06 23:00:01] {383} INFO - trial 1 config: {'C': 1.0, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 23:00:06] {1938} INFO -  at 717.0s,	estimator lrl1's best error=0.1695,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:00:06] {1748} INFO - iteration 85, current learner lrl1
# [flaml.tune.tune: 10-06 23:00:06] {383} INFO - trial 1 config: {'C': 0.24999999999999997, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 23:00:09] {1938} INFO -  at 720.5s,	estimator lrl1's best error=0.1685,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:00:09] {1748} INFO - iteration 86, current learner lrl1
# [flaml.tune.tune: 10-06 23:00:09] {383} INFO - trial 1 config: {'C': 0.06249999999999999, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 23:00:11] {1938} INFO -  at 722.5s,	estimator lrl1's best error=0.1685,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:00:11] {1748} INFO - iteration 87, current learner catboost
# [flaml.tune.tune: 10-06 23:00:11] {383} INFO - trial 1 config: {'early_stopping_rounds': 10, 'learning_rate': 0.005, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 23:00:39] {1938} INFO -  at 750.0s,	estimator catboost's best error=0.1537,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:00:39] {1748} INFO - iteration 88, current learner extra_tree
# [flaml.tune.tune: 10-06 23:00:39] {383} INFO - trial 1 config: {'n_estimators': 12, 'max_features': 0.45211953047173764, 'max_leaves': 15, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 23:00:39] {1938} INFO -  at 750.4s,	estimator extra_tree's best error=0.1809,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:00:39] {1748} INFO - iteration 89, current learner rf
# [flaml.tune.tune: 10-06 23:00:39] {383} INFO - trial 1 config: {'n_estimators': 17, 'max_features': 0.495674114697, 'max_leaves': 121, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 23:00:45] {1938} INFO -  at 756.0s,	estimator rf's best error=0.1789,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:00:45] {1748} INFO - iteration 90, current learner rf
# [flaml.tune.tune: 10-06 23:00:45] {383} INFO - trial 1 config: {'n_estimators': 12, 'max_features': 0.45211953047173764, 'max_leaves': 15, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-06 23:00:47] {1938} INFO -  at 758.2s,	estimator rf's best error=0.1789,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:00:47] {1748} INFO - iteration 91, current learner lrl1
# [flaml.tune.tune: 10-06 23:00:47] {383} INFO - trial 1 config: {'C': 0.24999999999999997, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 23:00:51] {1938} INFO -  at 762.2s,	estimator lrl1's best error=0.1627,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:00:51] {1748} INFO - iteration 92, current learner lrl1
# [flaml.tune.tune: 10-06 23:00:51] {383} INFO - trial 1 config: {'C': 0.06249999999999999, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 23:00:56] {1938} INFO -  at 766.9s,	estimator lrl1's best error=0.1627,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:00:56] {1748} INFO - iteration 93, current learner lrl1
# [flaml.tune.tune: 10-06 23:00:56] {383} INFO - trial 1 config: {'C': 1.0, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 23:01:03] {1938} INFO -  at 774.8s,	estimator lrl1's best error=0.1627,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:01:03] {1748} INFO - iteration 94, current learner lrl1
# [flaml.tune.tune: 10-06 23:01:03] {383} INFO - trial 1 config: {'C': 0.24999999999999997, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-06 23:01:16] {1938} INFO -  at 787.9s,	estimator lrl1's best error=0.1611,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:01:16] {1748} INFO - iteration 95, current learner catboost
# [flaml.tune.tune: 10-06 23:01:16] {383} INFO - trial 1 config: {'early_stopping_rounds': 11, 'learning_rate': 0.2, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 23:01:32] {1938} INFO -  at 803.7s,	estimator catboost's best error=0.1537,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:01:32] {1748} INFO - iteration 96, current learner lgbm
# [flaml.tune.tune: 10-06 23:01:32] {383} INFO - trial 1 config: {'n_estimators': 214, 'num_leaves': 25, 'min_child_samples': 2, 'learning_rate': 0.11497462458887524, 'log_max_bin': 7, 'colsample_bytree': 0.8247409754086196, 'reg_alpha': 0.0036125110636563273, 'reg_lambda': 0.029240370054481855, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-06 23:03:15] {1938} INFO -  at 906.2s,	estimator lgbm's best error=0.1455,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:03:15] {1748} INFO - iteration 97, current learner lrl1
# [flaml.tune.tune: 10-06 23:03:15] {383} INFO - trial 1 config: {'C': 0.06249999999999999, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-06 23:03:28] {1938} INFO -  at 919.7s,	estimator lrl1's best error=0.1611,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:03:28] {1748} INFO - iteration 98, current learner catboost
# [flaml.tune.tune: 10-06 23:03:28] {383} INFO - trial 1 config: {'early_stopping_rounds': 11, 'learning_rate': 0.0943289179113066, 'FLAML_sample_size': 40000}
# [flaml.automl: 10-06 23:03:48] {1938} INFO -  at 939.3s,	estimator catboost's best error=0.1537,	best estimator lgbm's best error=0.1455
# [flaml.automl: 10-06 23:03:48] {1748} INFO - iteration 99, current learner catboost
# [flaml.tune.tune: 10-06 23:03:48] {383} INFO - trial 1 config: {'early_stopping_rounds': 10, 'learning_rate': 0.09999999999999996, 'FLAML_sample_size': 160000}
# ...
# [flaml.automl: 10-07 00:24:24] {1748} INFO - iteration 139, current learner lgbm
# [flaml.tune.tune: 10-07 00:24:24] {383} INFO - trial 1 config: {'n_estimators': 2179, 'num_leaves': 4, 'min_child_samples': 4, 'learning_rate': 0.040851865164086155, 'log_max_bin': 10, 'colsample_bytree': 0.8748414275196131, 'reg_alpha': 0.02745801997314954, 'reg_lambda': 0.08311309439878294, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-07 00:27:42] {1938} INFO -  at 5973.3s,	estimator lgbm's best error=0.1442,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 00:27:42] {1748} INFO - iteration 140, current learner xgboost
# [flaml.tune.tune: 10-07 00:27:42] {383} INFO - trial 1 config: {'n_estimators': 363, 'max_leaves': 64, 'min_child_weight': 64.14004485500153, 'learning_rate': 0.0480431753835877, 'subsample': 0.8413048297641477, 'colsample_bylevel': 0.430461431952924, 'colsample_bytree': 0.712906857857845, 'reg_alpha': 0.001058358871316641, 'reg_lambda': 37.17124858932945, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-07 00:29:52] {1938} INFO -  at 6103.0s,	estimator xgboost's best error=0.1482,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 00:29:52] {1748} INFO - iteration 141, current learner rf
# [flaml.tune.tune: 10-07 00:29:52] {383} INFO - trial 1 config: {'n_estimators': 36, 'max_features': 0.5229242759531132, 'max_leaves': 74, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-07 00:30:03] {1938} INFO -  at 6114.3s,	estimator rf's best error=0.1753,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 00:30:03] {1748} INFO - iteration 142, current learner xgboost
# [flaml.tune.tune: 10-07 00:30:03] {383} INFO - trial 1 config: {'n_estimators': 277, 'max_leaves': 39, 'min_child_weight': 20.531012353518616, 'learning_rate': 0.020890565272497986, 'subsample': 0.93649839568779, 'colsample_bylevel': 0.23338384524947003, 'colsample_bytree': 0.741299553682497, 'reg_alpha': 0.0009765625, 'reg_lambda': 14.451665100581856, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-07 00:31:36] {1938} INFO -  at 6207.8s,	estimator xgboost's best error=0.1482,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 00:31:36] {1748} INFO - iteration 143, current learner rf
# [flaml.tune.tune: 10-07 00:31:36] {383} INFO - trial 1 config: {'n_estimators': 138, 'max_features': 0.97471066939307, 'max_leaves': 42, 'criterion': 'gini', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-07 00:32:10] {1938} INFO -  at 6241.4s,	estimator rf's best error=0.1753,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 00:32:10] {1748} INFO - iteration 144, current learner xgboost
# [flaml.tune.tune: 10-07 00:32:10] {383} INFO - trial 1 config: {'n_estimators': 476, 'max_leaves': 105, 'min_child_weight': 128.0, 'learning_rate': 0.11048751773015911, 'subsample': 0.7461112638405054, 'colsample_bylevel': 0.6275390186563781, 'colsample_bytree': 0.684514162033193, 'reg_alpha': 0.0030995186585984886, 'reg_lambda': 95.60847916646617, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-07 00:35:24] {1938} INFO -  at 6435.4s,	estimator xgboost's best error=0.1482,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 00:35:24] {1748} INFO - iteration 145, current learner xgboost
# [flaml.tune.tune: 10-07 00:35:24] {383} INFO - trial 1 config: {'n_estimators': 71, 'max_leaves': 62, 'min_child_weight': 33.154738970885326, 'learning_rate': 0.1009375073051797, 'subsample': 0.7898003705121343, 'colsample_bylevel': 0.3213355741937919, 'colsample_bytree': 0.5926374971657408, 'reg_alpha': 0.004048259869172362, 'reg_lambda': 82.41749275648611, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-07 00:35:58] {1938} INFO -  at 6469.3s,	estimator xgboost's best error=0.1482,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 00:35:58] {1748} INFO - iteration 146, current learner catboost
# [flaml.tune.tune: 10-07 00:35:58] {383} INFO - trial 1 config: {'early_stopping_rounds': 10, 'learning_rate': 0.12988271044796598, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-07 00:39:06] {1938} INFO -  at 6657.5s,	estimator catboost's best error=0.1467,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 00:39:06] {1748} INFO - iteration 147, current learner lgbm
# [flaml.tune.tune: 10-07 00:39:06] {383} INFO - trial 1 config: {'n_estimators': 949, 'num_leaves': 4, 'min_child_samples': 6, 'learning_rate': 0.04094368410197193, 'log_max_bin': 9, 'colsample_bytree': 0.6135623127158465, 'reg_alpha': 0.002093831532565935, 'reg_lambda': 1.3731221583964888, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-07 00:42:16] {1938} INFO -  at 6847.8s,	estimator lgbm's best error=0.1442,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 00:42:16] {1748} INFO - iteration 148, current learner lgbm
# [flaml.tune.tune: 10-07 00:42:16] {383} INFO - trial 1 config: {'n_estimators': 15790, 'num_leaves': 20, 'min_child_samples': 5, 'learning_rate': 0.07080628818561464, 'log_max_bin': 10, 'colsample_bytree': 0.8146365602724822, 'reg_alpha': 0.0018633999877243066, 'reg_lambda': 0.014164915147400217, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-07 01:36:27] {1938} INFO -  at 10098.2s,	estimator lgbm's best error=0.1442,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 01:36:27] {1748} INFO - iteration 149, current learner rf
# [flaml.tune.tune: 10-07 01:36:27] {383} INFO - trial 1 config: {'n_estimators': 69, 'max_features': 1.0, 'max_leaves': 87, 'criterion': 'entropy', 'FLAML_sample_size': 10000}
# [flaml.automl: 10-07 01:37:05] {1938} INFO -  at 10136.9s,	estimator rf's best error=0.1753,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 01:37:05] {1748} INFO - iteration 150, current learner lgbm
# [flaml.tune.tune: 10-07 01:37:05] {383} INFO - trial 1 config: {'n_estimators': 611, 'num_leaves': 7, 'min_child_samples': 8, 'learning_rate': 0.06713125336510266, 'log_max_bin': 9, 'colsample_bytree': 0.7179581391410879, 'reg_alpha': 0.0039143924858597206, 'reg_lambda': 0.7630010995287293, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-07 01:40:01] {1938} INFO -  at 10312.5s,	estimator lgbm's best error=0.1442,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 01:40:01] {1748} INFO - iteration 151, current learner rf
# [flaml.tune.tune: 10-07 01:40:01] {383} INFO - trial 1 config: {'n_estimators': 71, 'max_features': 0.7139326796387357, 'max_leaves': 56, 'criterion': 'entropy', 'FLAML_sample_size': 40000}
# [flaml.automl: 10-07 01:41:15] {1938} INFO -  at 10386.8s,	estimator rf's best error=0.1729,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 01:41:15] {1748} INFO - iteration 152, current learner rf
# [flaml.tune.tune: 10-07 01:41:15] {383} INFO - trial 1 config: {'n_estimators': 86, 'max_features': 0.7525605734738157, 'max_leaves': 38, 'criterion': 'entropy', 'FLAML_sample_size': 40000}
# [flaml.automl: 10-07 01:42:47] {1938} INFO -  at 10478.8s,	estimator rf's best error=0.1729,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 01:42:47] {1748} INFO - iteration 153, current learner xgboost
# [flaml.tune.tune: 10-07 01:42:47] {383} INFO - trial 1 config: {'n_estimators': 1843, 'max_leaves': 66, 'min_child_weight': 124.08317729825107, 'learning_rate': 0.022867086403863694, 'subsample': 0.8928092890161611, 'colsample_bylevel': 0.5395872897120562, 'colsample_bytree': 0.8331762185499493, 'reg_alpha': 0.0009765625, 'reg_lambda': 16.764665794580228, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-07 01:53:38] {1938} INFO -  at 11129.7s,	estimator xgboost's best error=0.1472,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 01:53:38] {1748} INFO - iteration 154, current learner catboost
# [flaml.tune.tune: 10-07 01:53:38] {383} INFO - trial 1 config: {'early_stopping_rounds': 11, 'learning_rate': 0.07699254169789, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-07 01:57:16] {1938} INFO -  at 11347.5s,	estimator catboost's best error=0.1467,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 01:57:16] {1748} INFO - iteration 155, current learner lgbm
# [flaml.tune.tune: 10-07 01:57:16] {383} INFO - trial 1 config: {'n_estimators': 24523, 'num_leaves': 12, 'min_child_samples': 3, 'learning_rate': 0.043185106050947636, 'log_max_bin': 10, 'colsample_bytree': 0.7102407338472408, 'reg_alpha': 0.000996743598444551, 'reg_lambda': 0.02549165246644438, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-07 03:04:32] {1938} INFO -  at 15383.0s,	estimator lgbm's best error=0.1442,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:04:32] {1748} INFO - iteration 156, current learner lgbm
# [flaml.tune.tune: 10-07 03:04:32] {383} INFO - trial 1 config: {'n_estimators': 601, 'num_leaves': 4, 'min_child_samples': 6, 'learning_rate': 0.07941547761129293, 'log_max_bin': 10, 'colsample_bytree': 0.7667913260618366, 'reg_alpha': 0.009621115433769915, 'reg_lambda': 0.3177233685611263, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-07 03:05:51] {1938} INFO -  at 15462.4s,	estimator lgbm's best error=0.1442,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:05:51] {1748} INFO - iteration 157, current learner lrl1
# [flaml.tune.tune: 10-07 03:05:51] {383} INFO - trial 1 config: {'C': 0.06249999999999999, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-07 03:07:08] {1938} INFO -  at 15539.4s,	estimator lrl1's best error=0.1603,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:07:08] {1748} INFO - iteration 158, current learner catboost
# [flaml.tune.tune: 10-07 03:07:08] {383} INFO - trial 1 config: {'early_stopping_rounds': 10, 'learning_rate': 0.005, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-07 03:09:31] {1938} INFO -  at 15682.5s,	estimator catboost's best error=0.1467,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:09:31] {1748} INFO - iteration 159, current learner rf
# [flaml.tune.tune: 10-07 03:09:31] {383} INFO - trial 1 config: {'n_estimators': 59, 'max_features': 0.6772875021918483, 'max_leaves': 83, 'criterion': 'gini', 'FLAML_sample_size': 40000}
# [flaml.automl: 10-07 03:10:22] {1938} INFO -  at 15733.7s,	estimator rf's best error=0.1729,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:10:22] {1748} INFO - iteration 160, current learner rf
# [flaml.tune.tune: 10-07 03:10:22] {383} INFO - trial 1 config: {'n_estimators': 151, 'max_features': 0.60318982891517, 'max_leaves': 40, 'criterion': 'gini', 'FLAML_sample_size': 40000}
# [flaml.automl: 10-07 03:11:43] {1938} INFO -  at 15814.3s,	estimator rf's best error=0.1729,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:11:43] {1748} INFO - iteration 161, current learner xgboost
# [flaml.tune.tune: 10-07 03:11:43] {383} INFO - trial 1 config: {'n_estimators': 1259, 'max_leaves': 403, 'min_child_weight': 128.0, 'learning_rate': 0.017860829351346443, 'subsample': 0.9492718545694211, 'colsample_bylevel': 0.4075608041858681, 'colsample_bytree': 0.8452108295036744, 'reg_alpha': 0.0009765625, 'reg_lambda': 44.079452193716776, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-07 03:16:31] {1938} INFO -  at 16102.6s,	estimator xgboost's best error=0.1472,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:16:31] {1748} INFO - iteration 162, current learner rf
# [flaml.tune.tune: 10-07 03:16:31] {383} INFO - trial 1 config: {'n_estimators': 33, 'max_features': 0.8450074033457011, 'max_leaves': 78, 'criterion': 'entropy', 'FLAML_sample_size': 40000}
# [flaml.automl: 10-07 03:17:30] {1938} INFO -  at 16161.6s,	estimator rf's best error=0.1729,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:17:30] {1748} INFO - iteration 163, current learner catboost
# [flaml.tune.tune: 10-07 03:17:30] {383} INFO - trial 1 config: {'early_stopping_rounds': 11, 'learning_rate': 0.2, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-07 03:19:37] {1938} INFO -  at 16288.8s,	estimator catboost's best error=0.1467,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:19:37] {1748} INFO - iteration 164, current learner extra_tree
# [flaml.tune.tune: 10-07 03:19:37] {383} INFO - trial 1 config: {'n_estimators': 34, 'max_features': 0.6474332373706322, 'max_leaves': 29, 'criterion': 'gini', 'FLAML_sample_size': 40000}
# [flaml.automl: 10-07 03:19:43] {1938} INFO -  at 16294.7s,	estimator extra_tree's best error=0.1750,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:19:43] {1748} INFO - iteration 165, current learner xgboost
# [flaml.tune.tune: 10-07 03:19:43] {383} INFO - trial 1 config: {'n_estimators': 2698, 'max_leaves': 11, 'min_child_weight': 84.91849847859247, 'learning_rate': 0.029276559913067452, 'subsample': 0.8363467234629011, 'colsample_bylevel': 0.6716137752382443, 'colsample_bytree': 0.8211416075962242, 'reg_alpha': 0.006535953249353212, 'reg_lambda': 6.376077859788618, 'FLAML_sample_size': 160000}
# [flaml.automl: 10-07 03:23:32] {1938} INFO -  at 16523.6s,	estimator xgboost's best error=0.1472,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:23:32] {1748} INFO - iteration 166, current learner rf
# [flaml.tune.tune: 10-07 03:23:32] {383} INFO - trial 1 config: {'n_estimators': 101, 'max_features': 0.48651847887892885, 'max_leaves': 39, 'criterion': 'entropy', 'FLAML_sample_size': 40000}
# [flaml.automl: 10-07 03:24:20] {1938} INFO -  at 16571.1s,	estimator rf's best error=0.1729,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:24:20] {1748} INFO - iteration 167, current learner catboost
# [flaml.tune.tune: 10-07 03:24:20] {383} INFO - trial 1 config: {'early_stopping_rounds': 10, 'learning_rate': 0.033085143303771984, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-07 03:24:33] {1938} INFO -  at 16584.0s,	estimator catboost's best error=0.1467,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:24:33] {1748} INFO - iteration 168, current learner catboost
# [flaml.tune.tune: 10-07 03:24:33] {383} INFO - trial 1 config: {'early_stopping_rounds': 11, 'learning_rate': 0.06480843659637783, 'FLAML_sample_size': 10000}
# [flaml.automl: 10-07 03:24:43] {1938} INFO -  at 16594.8s,	estimator catboost's best error=0.1467,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:24:43] {1748} INFO - iteration 169, current learner extra_tree
# [flaml.tune.tune: 10-07 03:24:43] {383} INFO - trial 1 config: {'n_estimators': 40, 'max_features': 1.0, 'max_leaves': 30, 'criterion': 'entropy', 'FLAML_sample_size': 40000}
# [flaml.automl: 10-07 03:24:55] {1938} INFO -  at 16606.6s,	estimator extra_tree's best error=0.1750,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:24:55] {1748} INFO - iteration 170, current learner lgbm
# [flaml.tune.tune: 10-07 03:24:55] {383} INFO - trial 1 config: {'n_estimators': 24954, 'num_leaves': 25, 'min_child_samples': 4, 'learning_rate': 0.03650510433362607, 'log_max_bin': 10, 'colsample_bytree': 0.6614075469264921, 'reg_alpha': 0.0009765625, 'reg_lambda': 0.06121727510565317, 'FLAML_sample_size': 900000}
# [flaml.automl: 10-07 03:48:23] {1938} INFO -  at 18014.7s,	estimator lgbm's best error=0.1442,	best estimator lgbm's best error=0.1442
# [flaml.automl: 10-07 03:48:23] {2043} INFO - selected model: LGBMClassifier(colsample_bytree=0.7140994364941643,
#                learning_rate=0.05384301529358282, max_bin=512,
#                min_child_samples=5, n_estimators=3872, num_leaves=9,
#                objective='binary', reg_alpha=0.001975258376030875,
#                reg_lambda=0.13946382635185836, verbose=-1)
# [flaml.automl: 10-07 03:53:40] {2104} INFO - retrain lgbm for 317.2s
# [flaml.automl: 10-07 03:53:41] {2110} INFO - retrained model: LGBMClassifier(colsample_bytree=0.7140994364941643,
#                learning_rate=0.05384301529358282, max_bin=512,
#                min_child_samples=5, n_estimators=914, num_leaves=9,
#                objective='binary', reg_alpha=0.001975258376030875,
#                reg_lambda=0.13946382635185836, verbose=-1)
# [flaml.automl: 10-07 03:53:41] {1539} INFO - fit succeeded
# [flaml.automl: 10-07 03:53:41] {1540} INFO - Time taken to find the best model: 3706.1066744327545

# %%
import pickle

# %%
filename = 'finalized_flaml_model_{}.sav'.format(time.time())
pickle.dump(model, open(filename, 'wb'))

# %%
submission_pred = model.predict(X_test)

# %%
submission_pred.shape
# Out:
# (500000,)

# %%
submit_final = pd.concat([ID_test,pd.DataFrame(submission_pred)],axis=1)
submit_final.shape
# Out:
# (500000, 2)

# %%
submit_final.to_csv('oct_AutoML_{}.csv'.format(time.time()),index_label=False)

# %%
from sklearn.metrics import roc_auc_score
small_pred = model.predict(X[:50000])
roc_auc = roc_auc_score(y[:50000],small_pred)
roc_auc
# Out:
# 0.770607072308618
